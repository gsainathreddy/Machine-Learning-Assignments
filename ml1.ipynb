# %% [markdown]
# <a href="https://colab.research.google.com/github/sainath6304796986/Machine-Learning-Assignments/blob/sai/ml1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Review Questions-I from MDSC-301(P)
#
# ----------------------------------------------------------------
# Author: Dr. Sampath Lonka
#
# Date: August 20, 2022
#
# ----------------------------------------------------------------

# %% [markdown]
# Q1. Which Linear Regression training algorithm can you use if you have
# a training set with millions of features?

# %% [markdown]
# Gradient Descent ,Batch gradient descent,stochastic Gradient descent

# %% [markdown]
# Q2. Suppose the features in your training set have very different scales.
# Which algorithms might suffer from this, and how? What can you
# do about it?

# %% [markdown]
# Clustering algortihms and linear regression  might suffer from this.
# clustering uses eculidean distance to form group and distance can be reduced to smaller amount
# In the same way in linear regression bring the feature values  bring to   lower value and the machine can learn things faster.

# %% [markdown]
# Q3.  Suppose you use Batch Gradient Descent and you plot the validation
# error at every epoch. If you notice that the validation error
# consistently goes up, what is likely going on? How can you fix this?

# %% [markdown]
# It might be due to increase in learning rate which causes this problem.If the training error increases then we should reduce the learning rate or else
# trainging error doesnot increase then model leads to overfitting and we can apply regularization technique

# %% [markdown]
# Q4. Is it a good idea to stop Mini-batch Gradient Descent immediately
# when the validation error goes up?

# %% [markdown]
# No,because mini batch gradient descent works on batches and if we stop validation error goes up then we might stop early before reaching optimimum value.

# %% [markdown]
# Q5. Suppose you are using Polynomial Regression. You plot the learning
# curves and you notice that there is a large gap between the training
# error and the validation error. What is happening? What are three
# ways to solve this?

# %% [markdown]
# If the validation error is more than the training error then it is caused by overfitting
# This can be  solved by applying following techinques
# 1.Ridge regression
# 2.Lasso Regression
# 3.By increasing the data size

# %% [markdown]
# Q6. Suppose you are using Ridge Regression and you notice that the
# training error and the validation error are almost equal and fairly
# high. Would you say that the model suffers from high bias or high
# variance? Should you increase the regularization hyperparameter $\alpha$
# or reduce it?

# %% [markdown]
# If the training error and validation error are  almost equal and high then the model is likely to  undergo underfitting.
# we should decrease hyperparameter.

# %% [markdown]
# Q7. Why would you want to use:
#    - Ridge Regression instead of plain Linear Regression (i.e., without any regularization)?
#    - Lasso instead of Ridge Regression?
#    - Elastic Net instead of Lasso?

# %% [markdown]
# ```
#
# ```
#
# Model with regularization performs better than model which is not regularized.So the ridge regression is better than plain linear regression.
#
# Lasso performs well if the parameters are close to zero and ridge performs well if they are many large parameters of about the same value.
#
# Elastic Net is hybrid of both lasso and ridge regression so it performs better than lasso.

# %% [markdown]
# Q8.  Can you name four of the main challenges in Machine Learning?

# %% [markdown]
# 1.Insufficent data for machine to learn about all its features.
#
# 2.Poor quality of data if the data consists of outliers errors and noise.
#
# 3.Overfitting and underfitting
#
# 4.Data mismatch

# %% [markdown]
# Q9. If your model performs great on the training data but generalizes
# poorly to new instances, what is happening? Can you name three
# possible solutions?

# %% [markdown]
# Overfitting is happening
#
# Three possible ways to solve this problem:
#
# cross valdiation: In cross validation we divide the data set into k folds and we work on k-1 folds and remaining 1 fold is used for testing
# cross validation allows to tune hyperparameters on training dataset not on test dataset
#
# Augementation of data : we need to provide sufficent data to model to learn if the data is less then we should provide data to model for example in image classification we have less images then use the same image and rotate and flip in different angles and use the same images for the classification.
#
# Regularization:l1 and l2 norm

# %% [markdown]
# Q10. What is a test set, and why would you want to use it?

# %% [markdown]
# Test set is  subset of data which is not exposed during training and this is used for only testing for final evalution

# %% [markdown]
# Q11.  What is the purpose of a validation set?

# %% [markdown]
# validation set is used for fine tuning model hyperparameters and evaluates the model performance during training

# %% [markdown]
# Q12. What are different loss functions? Exaplain their importance?

# %% [markdown]
# Regression:
# Mean square error:
# Its  average of square difference between actual and predicted value.
# mse=${\sum_{i=1}^{n}\frac{(y_{i} - \hat{y}_{i})^2}{n}}$
# Mean absolute error:
# Its actual difference between actual and predicted value.
# mae=${\sum_{i=1}^{n}\frac{|y_{i} - \hat{y}_{i}|}{n}}$
# Huber loss error:
# Its combinations of mse and mae
# ![10_common-loss-functions.jpg](data:image/jpeg;base64,...)
#
#
#
#
#
# Classification
# Binary cross entropy it is used for classification of binary classification problems.cross entropy loss decreases the predicted probality converges to actual value.
# ![2_common-loss-functions.png](data:image/png;base64,...)
#
#
#
#  Hinge Loss:
#  hinge loss is used for svm
#  hinge loss penilizes the the right predictions and wrong predictions that are not confident.
#  ![4_common-loss-functions.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Q13. Explain the following:
#     - Gradient descent
#     - Mini-batch gradient descent
#     - Batch gradient, and
#     - Stochastic Gradient Descent

# %% [markdown]
# Gradient descent:Its an iterative approach first order dervaite which is used to find local minima and maxima of given function.
# Its used to minimise the cost function /loss function
#
# In Batch Gradient Descent all the training data is taken into consideration to take a single step.
# We take the average of the gradients of all the training examples and then use that mean gradient to update our parameters.
# So that’s just one step of gradient descent in one epoch.
#
# Mini-batch gradient is both mix of gradient descent and stochastic gradient descent
# In this approach we convert data into small subsets and computes the gradients for each approach
#
#
# Stochastic Gradient Descent is an optimazation algortihm which is used for finding model parameters that corresponds to actual value to predicted value

# %% [markdown]
# Q14. What is learning rate?

# %% [markdown]
# Learning rate is hyperparameter which controls weights of our neural networks with respect to loss gradient
#
# Lower the learning  rate helps the neural network to learn better compared to higher learning rate.

# %% [markdown]
# Q15. Define the following terms. Explain their importance in the data analysis.
#     - $R^2$
#     - Adjusted $R^2$

# %% [markdown]
# R square is used to determine correlation between predictor and target
#
# Its ratio of resiudal sum of squares and  total sum of squares
#
# R^2=1-(rss/tss)
#
# R2 assumes that every single variable explains the variation in the dependent variable.
# The adjusted R2 tells you the percentage of variation explained by only the independent variables that actually affect the dependent variable.
#
#
#
# Adjusted R^2:
#
# The adjusted R2 will penalize you for adding independent variables that do not fit the model.
#
# Adjusted R2 will compensate for this by that penalizing you for those extra variables.

# %% [markdown]
# Q16. Explain One-Hot Encoding and Label Encoding.

# %% [markdown]
# One hot encoding is used for  converting categorical variables to numerical value. In this categorical variable unique values are seperated by making new columns and they are filled with the binary values.
#
# Label Encoding is used for converting categorical values to numerical values but they are arranged in sequence order .
# For example if data set contains country names then they are order India =0,USA=1,ENG=2

# %% [markdown]
# Q17. What are the assumption on Naive Bayes algorithm in classification?

# %% [markdown]
# In Naive Bayes algorithm all features are important and all they contribute  equal contribution to model.
#
# All features are independent .

# %% [markdown]
# Q18. What is the difference between classification and regression?

# %% [markdown]
# classification is used for predicting the discrete values
#
# The algos are logastic regression svm
#
# Regression is used for predicting the continuous values

# %% [markdown]
# Q19. How to ensure that the model is not overfitting?

# %% [markdown]
# Data Augemenation
#
# Regularization
#
# Early stopping
#
# Cross Validation

# %% [markdown]
# Q20. List the main advantage of Naive Bayes?

# %% [markdown]
#  Naive Bayes is used for both  discrete and continuous data
#
#  Easy implementation
#
#  Very fast
#
# Used for Multi class prediction

# %% [markdown]
# Q21. What you shoud do when your model is suffereing from:
#     - Low bias and high variance?
#     - High bias and low variance?

# %% [markdown]
# High varaince means overfitting so we can  reduce the complexity of model in
# which we can tradeoff good bias and variance.
#
# High bias and low variance in this situation we can add more data for model to learn more and give the better predictions on both training test set

# %% [markdown]
# Q22. What is the 'Naive' in the Naive Bayes Classifier?

# %% [markdown]
# Naive means occurance of certain feature is independent of other feature

# %% [markdown]
# Q23. What is bias-variance tradeoff in Machine Learning ?

# %% [markdown]
# Bias is known as difference prediction and correct value
#
# Bias  being on high it gives error on both training and testing data set
#
# High bias leads to Underfitting
#
# Variability of model prediction for a given data point which tells us spread of our data is called the variance of the model.
#
# The data with high variance has very complex fitting the training data.
#
# When model is on high variance it is then said to be overfitting
#
# The algorthim can be too simple by high bias and low variance which causes problem in same way low bias and high variance which causes problem
#
# So there is tradeoff between bias and variance

# %% [markdown]
# Q24. Explain different trade-offs in Machine Learning algorithms?

# %% [markdown]
# Bias variance trade off:
#
# There is a tradeoff between a model's ability to minimize bias and variance which is referred to as the best solution for selecting a value of Regularization constant.
#
# Proper understanding of these errors would help to avoid the overfitting and underfitting of a data set while training the algorithm
#
# Precision and recall:
# Precision is calculated by dividing the true positives by anything that was predicted as a positive.
#
# Recall (or True Positive Rate) is calculated by dividing the true positives by anything that should have been predicted as positive.

# %% [markdown]
# Q25. What is cross-validation and how it is useful in traing ML models?

# %% [markdown]
# In cross validation we divide the data set into k folds and we work on k-1 folds and remaining 1 fold is used for testing.
#
# cross validation allows to tune hyperparameters on training dataset not on test dataset.
#
# Cross validation is used to to measure the model performance
#
# It also prevents the data from overfitting
